# %% [markdown]
# # Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.

# %% [markdown]
# ##### Copyright
# **Author:** [hfawaz](https://github.com/hfawaz/)<br>
# **Date created:** 2020/07/21<br>
# **Last modified:** 2021/07/16<br>
# **Description:** Training a timeseries classifier from scratch on the FordA dataset from the UCR/UEA archive.

# %% [markdown]
# ## Introduction
#
# This example shows how to do timeseries classification from scratch, starting from raw
# CSV timeseries files on disk. We demonstrate the workflow on the FordA dataset from the
# [UCR/UEA archive](https://www.cs.ucr.edu/%7Eeamonn/time_series_data_2018/).

# %% [markdown]
# ## Setup

# %%
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2022-11-23 16:07:25.820085: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-23 16:07:29.400861: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-11-23 16:07:35.899491: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-11-23 16:07:35.899878: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-11-23 16:07:35.899900: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %% [markdown]
# ## Load the data: the FordA dataset
#
# ### Dataset description
#
# The dataset we are using here is called FordA.
# The data comes from the UCR archive.
# The dataset contains 3601 training instances and another 1320 testing instances.
# Each timeseries corresponds to a measurement of engine noise captured by a motor sensor.
# For this task, the goal is to automatically detect the presence of a specific issue with
# the engine. The problem is a balanced binary classification task. The full description of
# this dataset can be found [here](http://www.j-wichard.de/publications/FordPaper.pdf).
#
# ### Read the TSV data
#
# We will use the `FordA_TRAIN` file for training and the
# `FordA_TEST` file for testing. The simplicity of this dataset
# allows us to demonstrate effectively how to use ConvNets for timeseries classification.
# In this file, the first column corresponds to the label.

# %%
def readucr(filename):
    data = np.loadtxt(filename, delimiter="\t")
    y = data[:, 0]
    x = data[:, 1:]
    return x, y.astype(int)


root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

# %% [markdown]
# ## Visualize the data
#
# Here we visualize one timeseries example for each class in the dataset.

# %%
classes = np.unique(np.concatenate((y_train, y_test), axis=0))

plt.figure()
for c in classes:
    c_x_train = x_train[y_train == c]
    plt.plot(c_x_train[0], label="class " + str(c))
plt.legend(loc="best")
plt.show()
plt.close()

# %% [markdown]
# ## Standardize the data
#
# Our timeseries are already in a single length (500). However, their values are
# usually in various ranges. This is not ideal for a neural network;
# in general we should seek to make the input values normalized.
# For this specific dataset, the data is already z-normalized: each timeseries sample
# has a mean equal to zero and a standard deviation equal to one. This type of
# normalization is very common for timeseries classification problems, see
# [Bagnall et al. (2016)](https://link.springer.com/article/10.1007/s10618-016-0483-9).
#
# Note that the timeseries data used here are univariate, meaning we only have one channel
# per timeseries example.
# We will therefore transform the timeseries into a multivariate one with one channel
# using a simple reshaping via numpy.
# This will allow us to construct a model that is easily applicable to multivariate time
# series.

# %%
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

# %% [markdown]
# Finally, in order to use `sparse_categorical_crossentropy`, we will have to count
# the number of classes beforehand.

# %%
num_classes = len(np.unique(y_train))

# %% [markdown]
# Now we shuffle the training set because we will be using the `validation_split` option
# later when training.

# %%
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]

# %% [markdown]
# Standardize the labels to positive integers.
# The expected labels will then be 0 and 1.

# %%
y_train[y_train == -1] = 0
y_test[y_test == -1] = 0

# %% [markdown]
# ## Build a model
#
# We build a Fully Convolutional Neural Network originally proposed in
# [this paper](https://arxiv.org/abs/1611.06455).
# The implementation is based on the TF 2 version provided
# [here](https://github.com/hfawaz/dl-4-tsc/).
# The following hyperparameters (kernel_size, filters, the usage of BatchNorm) were found
# via random search using [KerasTuner](https://github.com/keras-team/keras-tuner).

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    gap = keras.layers.GlobalAveragePooling1D()(conv3)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=x_train.shape[1:])
keras.utils.plot_model(model, show_shapes=True)
# Out:
# 2022-11-23 16:07:44.154232: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda/lib64:/usr/local/cuda/lib:/usr/local/lib/x86_64-linux-gnu:/usr/local/nvidia/lib:/usr/local/nvidia/lib64:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-11-23 16:07:44.154936: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-23 16:07:44.154976: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (ada9557f50df): /proc/driver/nvidia/version does not exist
# 2022-11-23 16:07:44.173934: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Train the model

# %%
epochs = 100
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 90/90 [==============================] - 8s 69ms/step - loss: 0.5747 - sparse_categorical_accuracy: 0.6847 - val_loss: 0.7585 - val_sparse_categorical_accuracy: 0.4840 - lr: 0.0010
# Epoch 2/100
# 90/90 [==============================] - 6s 66ms/step - loss: 0.4625 - sparse_categorical_accuracy: 0.7649 - val_loss: 0.8053 - val_sparse_categorical_accuracy: 0.4840 - lr: 0.0010
# Epoch 3/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.4358 - sparse_categorical_accuracy: 0.7753 - val_loss: 0.7593 - val_sparse_categorical_accuracy: 0.4840 - lr: 0.0010
# Epoch 4/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.4252 - sparse_categorical_accuracy: 0.7903 - val_loss: 0.6721 - val_sparse_categorical_accuracy: 0.5811 - lr: 0.0010
# Epoch 5/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.4114 - sparse_categorical_accuracy: 0.7920 - val_loss: 0.5550 - val_sparse_categorical_accuracy: 0.6824 - lr: 0.0010
# Epoch 6/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.4075 - sparse_categorical_accuracy: 0.8000 - val_loss: 0.5125 - val_sparse_categorical_accuracy: 0.6713 - lr: 0.0010
# Epoch 7/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.4080 - sparse_categorical_accuracy: 0.7976 - val_loss: 0.6399 - val_sparse_categorical_accuracy: 0.6006 - lr: 0.0010
# Epoch 8/100
# 90/90 [==============================] - 8s 91ms/step - loss: 0.3905 - sparse_categorical_accuracy: 0.8094 - val_loss: 0.5209 - val_sparse_categorical_accuracy: 0.7060 - lr: 0.0010
# Epoch 9/100
# 90/90 [==============================] - 5s 61ms/step - loss: 0.3949 - sparse_categorical_accuracy: 0.8104 - val_loss: 0.3608 - val_sparse_categorical_accuracy: 0.8128 - lr: 0.0010
# Epoch 10/100
# 90/90 [==============================] - 6s 64ms/step - loss: 0.3673 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.3479 - val_sparse_categorical_accuracy: 0.8530 - lr: 0.0010
# Epoch 11/100
# 90/90 [==============================] - 6s 64ms/step - loss: 0.3872 - sparse_categorical_accuracy: 0.8198 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8488 - lr: 0.0010
# Epoch 12/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.3693 - sparse_categorical_accuracy: 0.8274 - val_loss: 0.3350 - val_sparse_categorical_accuracy: 0.8502 - lr: 0.0010
# Epoch 13/100
# 90/90 [==============================] - 6s 69ms/step - loss: 0.3610 - sparse_categorical_accuracy: 0.8257 - val_loss: 0.7930 - val_sparse_categorical_accuracy: 0.6852 - lr: 0.0010
# Epoch 14/100
# 90/90 [==============================] - 5s 61ms/step - loss: 0.3496 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.3262 - val_sparse_categorical_accuracy: 0.8322 - lr: 0.0010
# Epoch 15/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3335 - sparse_categorical_accuracy: 0.8535 - val_loss: 0.5161 - val_sparse_categorical_accuracy: 0.7004 - lr: 0.0010
# Epoch 16/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.3389 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.3130 - val_sparse_categorical_accuracy: 0.8571 - lr: 0.0010
# Epoch 17/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3375 - sparse_categorical_accuracy: 0.8469 - val_loss: 0.2843 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 18/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3195 - sparse_categorical_accuracy: 0.8653 - val_loss: 0.4177 - val_sparse_categorical_accuracy: 0.7420 - lr: 0.0010
# Epoch 19/100
# 90/90 [==============================] - 6s 61ms/step - loss: 0.3120 - sparse_categorical_accuracy: 0.8615 - val_loss: 0.3659 - val_sparse_categorical_accuracy: 0.8197 - lr: 0.0010
# Epoch 20/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3083 - sparse_categorical_accuracy: 0.8684 - val_loss: 0.5155 - val_sparse_categorical_accuracy: 0.7074 - lr: 0.0010
# Epoch 21/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3066 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.4224 - val_sparse_categorical_accuracy: 0.7836 - lr: 0.0010
# Epoch 22/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.3123 - sparse_categorical_accuracy: 0.8639 - val_loss: 0.2784 - val_sparse_categorical_accuracy: 0.8849 - lr: 0.0010
# Epoch 23/100
# 90/90 [==============================] - 6s 67ms/step - loss: 0.2858 - sparse_categorical_accuracy: 0.8885 - val_loss: 0.2878 - val_sparse_categorical_accuracy: 0.8863 - lr: 0.0010
# Epoch 24/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.3128 - sparse_categorical_accuracy: 0.8642 - val_loss: 0.3218 - val_sparse_categorical_accuracy: 0.8128 - lr: 0.0010
# Epoch 25/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2953 - sparse_categorical_accuracy: 0.8712 - val_loss: 0.3490 - val_sparse_categorical_accuracy: 0.8058 - lr: 0.0010
# Epoch 26/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2858 - sparse_categorical_accuracy: 0.8837 - val_loss: 0.2932 - val_sparse_categorical_accuracy: 0.8571 - lr: 0.0010
# Epoch 27/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.8830 - val_loss: 0.6499 - val_sparse_categorical_accuracy: 0.6782 - lr: 0.0010
# Epoch 28/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.2768 - sparse_categorical_accuracy: 0.8854 - val_loss: 0.4603 - val_sparse_categorical_accuracy: 0.7254 - lr: 0.0010
# Epoch 29/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2754 - sparse_categorical_accuracy: 0.8872 - val_loss: 0.2616 - val_sparse_categorical_accuracy: 0.8807 - lr: 0.0010
# Epoch 30/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2641 - sparse_categorical_accuracy: 0.8972 - val_loss: 0.2383 - val_sparse_categorical_accuracy: 0.9071 - lr: 0.0010
# Epoch 31/100
# 90/90 [==============================] - 6s 61ms/step - loss: 0.2625 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.2404 - val_sparse_categorical_accuracy: 0.9029 - lr: 0.0010
# Epoch 32/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2663 - sparse_categorical_accuracy: 0.8924 - val_loss: 0.4496 - val_sparse_categorical_accuracy: 0.7767 - lr: 0.0010
# Epoch 33/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2659 - sparse_categorical_accuracy: 0.8934 - val_loss: 0.2816 - val_sparse_categorical_accuracy: 0.8752 - lr: 0.0010
# Epoch 34/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.2683 - sparse_categorical_accuracy: 0.8882 - val_loss: 0.3017 - val_sparse_categorical_accuracy: 0.8821 - lr: 0.0010
# Epoch 35/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2840 - val_sparse_categorical_accuracy: 0.8779 - lr: 0.0010
# Epoch 36/100
# 90/90 [==============================] - 6s 61ms/step - loss: 0.2573 - sparse_categorical_accuracy: 0.9000 - val_loss: 0.2833 - val_sparse_categorical_accuracy: 0.8655 - lr: 0.0010
# Epoch 37/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2567 - sparse_categorical_accuracy: 0.8979 - val_loss: 0.4643 - val_sparse_categorical_accuracy: 0.7420 - lr: 0.0010
# Epoch 38/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2543 - sparse_categorical_accuracy: 0.8979 - val_loss: 0.2314 - val_sparse_categorical_accuracy: 0.9015 - lr: 0.0010
# Epoch 39/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2483 - sparse_categorical_accuracy: 0.9035 - val_loss: 0.2062 - val_sparse_categorical_accuracy: 0.9168 - lr: 0.0010
# Epoch 40/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2562 - sparse_categorical_accuracy: 0.8948 - val_loss: 0.4152 - val_sparse_categorical_accuracy: 0.7795 - lr: 0.0010
# Epoch 41/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2392 - sparse_categorical_accuracy: 0.9038 - val_loss: 0.2273 - val_sparse_categorical_accuracy: 0.9071 - lr: 0.0010
# Epoch 42/100
# 90/90 [==============================] - 6s 61ms/step - loss: 0.2504 - sparse_categorical_accuracy: 0.8976 - val_loss: 0.2189 - val_sparse_categorical_accuracy: 0.9085 - lr: 0.0010
# Epoch 43/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.2382 - sparse_categorical_accuracy: 0.8993 - val_loss: 0.2058 - val_sparse_categorical_accuracy: 0.9182 - lr: 0.0010
# Epoch 44/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2352 - sparse_categorical_accuracy: 0.9052 - val_loss: 0.2827 - val_sparse_categorical_accuracy: 0.8738 - lr: 0.0010
# Epoch 45/100
# 90/90 [==============================] - 6s 67ms/step - loss: 0.2333 - sparse_categorical_accuracy: 0.9000 - val_loss: 1.2121 - val_sparse_categorical_accuracy: 0.6103 - lr: 0.0010
# Epoch 46/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.2415 - sparse_categorical_accuracy: 0.9028 - val_loss: 0.2112 - val_sparse_categorical_accuracy: 0.9223 - lr: 0.0010
# Epoch 47/100
# 90/90 [==============================] - 5s 58ms/step - loss: 0.2274 - sparse_categorical_accuracy: 0.9139 - val_loss: 0.2230 - val_sparse_categorical_accuracy: 0.9209 - lr: 0.0010
# Epoch 48/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2271 - sparse_categorical_accuracy: 0.9087 - val_loss: 0.2243 - val_sparse_categorical_accuracy: 0.9057 - lr: 0.0010
# Epoch 49/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2316 - sparse_categorical_accuracy: 0.9069 - val_loss: 1.2730 - val_sparse_categorical_accuracy: 0.7087 - lr: 0.0010
# Epoch 50/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.2298 - sparse_categorical_accuracy: 0.9062 - val_loss: 0.7263 - val_sparse_categorical_accuracy: 0.6657 - lr: 0.0010
# Epoch 51/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2222 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.2036 - val_sparse_categorical_accuracy: 0.9057 - lr: 0.0010
# Epoch 52/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2108 - sparse_categorical_accuracy: 0.9128 - val_loss: 0.2095 - val_sparse_categorical_accuracy: 0.9057 - lr: 0.0010
# Epoch 53/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.2114 - sparse_categorical_accuracy: 0.9160 - val_loss: 0.3796 - val_sparse_categorical_accuracy: 0.8114 - lr: 0.0010
# Epoch 54/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9146 - val_loss: 0.9609 - val_sparse_categorical_accuracy: 0.6616 - lr: 0.0010
# Epoch 55/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.2127 - sparse_categorical_accuracy: 0.9111 - val_loss: 0.2245 - val_sparse_categorical_accuracy: 0.9057 - lr: 0.0010
# Epoch 56/100
# 90/90 [==============================] - 6s 71ms/step - loss: 0.2039 - sparse_categorical_accuracy: 0.9205 - val_loss: 0.5986 - val_sparse_categorical_accuracy: 0.7295 - lr: 0.0010
# Epoch 57/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.1909 - sparse_categorical_accuracy: 0.9295 - val_loss: 0.1801 - val_sparse_categorical_accuracy: 0.9320 - lr: 0.0010
# Epoch 58/100
# 90/90 [==============================] - 6s 64ms/step - loss: 0.1976 - sparse_categorical_accuracy: 0.9243 - val_loss: 0.4777 - val_sparse_categorical_accuracy: 0.7725 - lr: 0.0010
# Epoch 59/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.1883 - sparse_categorical_accuracy: 0.9285 - val_loss: 0.8287 - val_sparse_categorical_accuracy: 0.6463 - lr: 0.0010
# Epoch 60/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.1774 - sparse_categorical_accuracy: 0.9309 - val_loss: 1.3909 - val_sparse_categorical_accuracy: 0.6630 - lr: 0.0010
# Epoch 61/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.1680 - sparse_categorical_accuracy: 0.9427 - val_loss: 0.1692 - val_sparse_categorical_accuracy: 0.9404 - lr: 0.0010
# Epoch 62/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1548 - sparse_categorical_accuracy: 0.9431 - val_loss: 0.5387 - val_sparse_categorical_accuracy: 0.7393 - lr: 0.0010
# Epoch 63/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1576 - sparse_categorical_accuracy: 0.9497 - val_loss: 0.2950 - val_sparse_categorical_accuracy: 0.8669 - lr: 0.0010
# Epoch 64/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.1525 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.1369 - val_sparse_categorical_accuracy: 0.9570 - lr: 0.0010
# Epoch 65/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.1522 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.8513 - val_sparse_categorical_accuracy: 0.7046 - lr: 0.0010
# Epoch 66/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.1502 - sparse_categorical_accuracy: 0.9438 - val_loss: 1.5007 - val_sparse_categorical_accuracy: 0.6768 - lr: 0.0010
# Epoch 67/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1291 - sparse_categorical_accuracy: 0.9573 - val_loss: 0.2390 - val_sparse_categorical_accuracy: 0.8793 - lr: 0.0010
# Epoch 68/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1377 - sparse_categorical_accuracy: 0.9517 - val_loss: 1.6900 - val_sparse_categorical_accuracy: 0.7143 - lr: 0.0010
# Epoch 69/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1334 - sparse_categorical_accuracy: 0.9549 - val_loss: 0.8865 - val_sparse_categorical_accuracy: 0.7171 - lr: 0.0010
# Epoch 70/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.1263 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.1766 - val_sparse_categorical_accuracy: 0.9251 - lr: 0.0010
# Epoch 71/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1303 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.5155 - val_sparse_categorical_accuracy: 0.7531 - lr: 0.0010
# Epoch 72/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1276 - sparse_categorical_accuracy: 0.9556 - val_loss: 0.1383 - val_sparse_categorical_accuracy: 0.9570 - lr: 0.0010
# Epoch 73/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.4138 - val_sparse_categorical_accuracy: 0.7864 - lr: 0.0010
# Epoch 74/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1299 - sparse_categorical_accuracy: 0.9528 - val_loss: 0.2893 - val_sparse_categorical_accuracy: 0.8266 - lr: 0.0010
# Epoch 75/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.1181 - sparse_categorical_accuracy: 0.9639 - val_loss: 1.9421 - val_sparse_categorical_accuracy: 0.6269 - lr: 0.0010
# Epoch 76/100
# 90/90 [==============================] - 6s 64ms/step - loss: 0.1265 - sparse_categorical_accuracy: 0.9524 - val_loss: 0.3046 - val_sparse_categorical_accuracy: 0.8239 - lr: 0.0010
# Epoch 77/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.1145 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1565 - val_sparse_categorical_accuracy: 0.9320 - lr: 0.0010
# Epoch 78/100
# 90/90 [==============================] - 5s 58ms/step - loss: 0.1219 - sparse_categorical_accuracy: 0.9563 - val_loss: 0.2563 - val_sparse_categorical_accuracy: 0.8669 - lr: 0.0010
# Epoch 79/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1132 - sparse_categorical_accuracy: 0.9632 - val_loss: 0.1922 - val_sparse_categorical_accuracy: 0.9209 - lr: 0.0010
# Epoch 80/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.1177 - sparse_categorical_accuracy: 0.9604 - val_loss: 0.1170 - val_sparse_categorical_accuracy: 0.9667 - lr: 0.0010
# Epoch 81/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.1178 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.3100 - val_sparse_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 82/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1104 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.1414 - val_sparse_categorical_accuracy: 0.9445 - lr: 0.0010
# Epoch 83/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1061 - sparse_categorical_accuracy: 0.9646 - val_loss: 1.8418 - val_sparse_categorical_accuracy: 0.6921 - lr: 0.0010
# Epoch 84/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1064 - sparse_categorical_accuracy: 0.9649 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9736 - lr: 0.0010
# Epoch 85/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1229 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.1133 - val_sparse_categorical_accuracy: 0.9639 - lr: 0.0010
# Epoch 86/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1125 - sparse_categorical_accuracy: 0.9590 - val_loss: 0.2784 - val_sparse_categorical_accuracy: 0.8641 - lr: 0.0010
# Epoch 87/100
# 90/90 [==============================] - 6s 66ms/step - loss: 0.1044 - sparse_categorical_accuracy: 0.9642 - val_loss: 0.1664 - val_sparse_categorical_accuracy: 0.9237 - lr: 0.0010
# Epoch 88/100
# 90/90 [==============================] - 6s 68ms/step - loss: 0.1114 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.1636 - val_sparse_categorical_accuracy: 0.9404 - lr: 0.0010
# Epoch 89/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1067 - sparse_categorical_accuracy: 0.9618 - val_loss: 0.7301 - val_sparse_categorical_accuracy: 0.7462 - lr: 0.0010
# Epoch 90/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9625 - val_loss: 0.2986 - val_sparse_categorical_accuracy: 0.8613 - lr: 0.0010
# Epoch 91/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0936 - sparse_categorical_accuracy: 0.9674 - val_loss: 0.3401 - val_sparse_categorical_accuracy: 0.8419 - lr: 0.0010
# Epoch 92/100
# 90/90 [==============================] - 6s 63ms/step - loss: 0.0998 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.2773 - val_sparse_categorical_accuracy: 0.8682 - lr: 0.0010
# Epoch 93/100
# 90/90 [==============================] - 6s 62ms/step - loss: 0.0996 - sparse_categorical_accuracy: 0.9667 - val_loss: 0.1924 - val_sparse_categorical_accuracy: 0.9209 - lr: 0.0010
# Epoch 94/100
# 90/90 [==============================] - 5s 60ms/step - loss: 0.1040 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.2608 - val_sparse_categorical_accuracy: 0.8849 - lr: 0.0010
# Epoch 95/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1154 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.1770 - val_sparse_categorical_accuracy: 0.9265 - lr: 0.0010
# Epoch 96/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1074 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.2070 - val_sparse_categorical_accuracy: 0.9015 - lr: 0.0010
# Epoch 97/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1074 - sparse_categorical_accuracy: 0.9660 - val_loss: 3.5650 - val_sparse_categorical_accuracy: 0.6061 - lr: 0.0010
# Epoch 98/100
# 90/90 [==============================] - 6s 65ms/step - loss: 0.1070 - sparse_categorical_accuracy: 0.9649 - val_loss: 1.6900 - val_sparse_categorical_accuracy: 0.6907 - lr: 0.0010
# Epoch 99/100
# 90/90 [==============================] - 6s 69ms/step - loss: 0.0918 - sparse_categorical_accuracy: 0.9667 - val_loss: 2.2296 - val_sparse_categorical_accuracy: 0.6713 - lr: 0.0010
# Epoch 100/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.1105 - sparse_categorical_accuracy: 0.9642 - val_loss: 1.1854 - val_sparse_categorical_accuracy: 0.6976 - lr: 0.0010

# %% [markdown]
# ## Evaluate model on test data

# %%
model = keras.models.load_model("best_model.h5")

test_loss, test_acc = model.evaluate(x_test, y_test)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 42/42 [==============================] - 1s 14ms/step - loss: 0.1117 - sparse_categorical_accuracy: 0.9705
# Test accuracy 0.9704545736312866
# Test loss 0.11171643435955048

# %% [markdown]
# ## Plot the model's training and validation loss

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %% [markdown]
# We can see how the training accuracy reaches almost 0.95 after 100 epochs.
# However, by observing the validation accuracy we can see how the network still needs
# training until it reaches almost 0.97 for both the validation and the training accuracy
# after 200 epochs. Beyond the 200th epoch, if we continue on training, the validation
# accuracy will start decreasing while the training accuracy will continue on increasing:
# the model starts overfitting.
